# %%
import os
import re

folder = '.'
filepaths = [os.path.join(folder, f) for f in os.listdir(folder)]

# %%
filepaths = [f.path for f in os.scandir('.') if f.is_file()]
dirpaths  = [f.path for f in os.scandir('.') if f.is_dir()]

def icacls_runner(path):
    return os.popen('icacls {}'.format(path))

def icacls_interpreter(icacls_output):
    temp_list = []
    for line in icacls_output:
        if ":" in line:
            line = re.sub('\s{3,}','',line)
            temp_list.append(re.split(':',line))
    return temp_list

# %%
for (dirpath, dirnames, filenames) in os.walk('.'):
    for f in filenames:
        print('FILE :', os.path.join(dirpath, f))
    for d in dirnames:
        print('DIRECTORY :', os.path.join(dirpath, d), icacls_interpreter(os.popen('icacls {}'.format(d))))
# Out:
# FILE : .\Untitled.ipynb
# DIRECTORY : .\.ipynb_checkpoints [['.ipynb_checkpoints NT AUTHORITY\\SYSTEM', '(I)(OI)(CI)(F)\n'], ['BUILTIN\\Administrators', '(I)(OI)(CI)(F)\n'], ['NIOWAVE\\aczyzewski', '(I)(OI)(CI)(F)\n']]
# FILE : .\.ipynb_checkpoints\Untitled-checkpoint.ipynb

# %%
import folderstats

df = folderstats.folderstats('../..', ignore_hidden=True)
for path in df['path']:
    print(icacls_interpreter(path))
# Out:
#       id                                               path  \
# 0      2                                  ../..\All_Code.py
# 1      4                    ../..\GPIB Programming\GUI-Java
# 2      6  ../..\GPIB Programming\GUI-Python\3-cell tunin...
# 3      7    ../..\GPIB Programming\GUI-Python\GPIB_FUNCS.py
# 4      8  ../..\GPIB Programming\GUI-Python\GUI_Tester.i...
# ..   ...                                                ...
# 530  533                ../..\Scripts\Undriven_Cavity.ipynb
# 531  534                   ../..\Scripts\WF_3d_Staircase.py
# 532  535           ../..\Scripts\Window_Frame_Scan__Grid.py
# 533  451                                      ../..\Scripts
# 534    1                                              ../..
#
#                         name extension       size               atime  \
# 0                   All_Code        py     195574 2021-01-08 13:49:01
# 1                   GUI-Java      None          0 2021-01-12 09:10:33
# 2              3-cell tuning        py      11889 2020-11-19 15:14:34
# 3                 GPIB_FUNCS        py       3850 2020-11-19 16:34:22
# 4                 GUI_Tester     ipynb      12932 2020-04-28 14:31:36
# ..                       ...       ...        ...                 ...
# 530          Undriven_Cavity     ipynb       2273 2020-12-18 09:47:43
# 531          WF_3d_Staircase        py       2879 2020-08-25 11:20:19
# 532  Window_Frame_Scan__Grid        py       4135 2020-06-08 11:52:14
# 533                  Scripts      None  457667234 2021-01-12 09:10:33
# 534                       ..      None  492684700 2021-01-12 09:10:33
#
#                   mtime               ctime  folder  num_files  depth  parent  \
# 0   2020-08-25 11:22:05 2020-08-25 11:11:08   False        NaN      0       1
# 1   2020-03-03 10:55:40 2020-03-06 11:35:12    True        0.0      2       3
# 2   2020-03-31 13:16:52 2020-04-22 11:20:10   False        NaN      2       5
# 3   2020-03-30 08:10:42 2020-03-16 15:47:54   False        NaN      2       5
# 4   2020-04-23 10:28:24 2020-03-16 15:47:54   False        NaN      2       5
# ..                  ...                 ...     ...        ...    ...     ...
# 530 2020-03-16 09:44:44 2020-03-16 08:55:46   False        NaN      1     451
# 531 2020-02-11 16:09:52 2020-02-11 16:09:52   False        NaN      1     451
# 532 2020-02-11 16:09:52 2020-02-11 16:09:52   False        NaN      1     451
# 533 2021-01-12 08:34:08 2020-02-11 16:09:52    True       74.0      1       1
# 534 2020-08-25 11:25:59 2020-02-11 16:09:50    True      446.0      0       0
#
#      uid
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 530    0
# 531    0
# 532    0
# 533    0
# 534    0
#
# [535 rows x 13 columns]
