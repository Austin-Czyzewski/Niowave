# %%
import pandas as pd
import numpy as np
import numpy.random as random
from datetime import datetime
import time
import os

from bokeh.plotting import figure
from bokeh.io import show, output_notebook, curdoc
from bokeh.models import LinearAxis, Range1d, BoxSelectTool
from bokeh.models.formatters import DatetimeTickFormatter, BasicTickFormatter
from bokeh.models import Legend
from bokeh.models.ranges import DataRange1d
from bokeh.plotting import figure, curdoc
from bokeh.driving import linear
from bokeh.palettes import Category20, Turbo256
from bokeh.layouts import column
from bokeh.models import Slider
from bokeh.models.widgets import CheckboxGroup
#from bokeh.io import show

# %%
import numpy as np
import pandas as pd
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import Spectral4
import time

time1 = time.time()
print("Importing")
LEU = pd.read_excel("Total_Core.xlsx", "LEU")
NU = pd.read_excel("Total_Core.xlsx", "NU")
Total = pd.read_excel("Total_Core.xlsx", "Total")
print("Imported, Importing took {:.1f} Seconds".format(time.time()-time1))
# Out:
# Importing
# Imported, Importing took 240.0 Seconds

# %%
TOOLS = "pan,xwheel_zoom, ywheel_zoom,box_zoom,reset,save,box_select"
p = figure(plot_width=800, plot_height=800, sizing_mode='stretch_both',\
           tools = TOOLS, \
           y_range=DataRange1d(bounds = (0,20)), \
           x_range = DataRange1d(bounds = (-1, 1.2* Total["Unnamed: 0"].iloc[-1])))#, x_axis_type="datetime")
p.title.text = 'Click on legend entries to hide the corresponding lines'
print("Processing Data")
elements = ["mo99", "xe133", "i133","tc99"]
time2 = time.time()
for data, name in zip([LEU, NU, Total], ["LEU", "NU", "Total"]):
# for data, name, color in zip([Total], ["Total"], Spectral4):
    df = pd.DataFrame(data)
#     df.index = pd.to_datetime(df.index)
    for ele, color in zip(elements,Spectral4):
        p.line(df["Unnamed: 0"], df[ele], line_width=2, color=color, alpha=0.8, legend_label=name + " " + ele)


p.legend.location = "top_left"
p.legend.click_policy="hide"
p.xaxis.axis_label = 'Days'
p.yaxis.axis_label = 'Activity of Mo-99 (Ci)'
print("Preparing HTML file, Processing took {:.1f} seconds".format(time.time()-time2))
time3 = time.time()
output_file("Total_Core_Interactive_Plot.html", title="Total Core Interactive Plot")
print("HTML Prep took {:.1f} seconds".format(time.time()-time3))
print("Total time to run was {:.1f} seconds".format(time.time()-time1))
show(p)
# Out:
# Processing Data
# Preparing HTML file, Processing took 0.2 seconds
# HTML Prep took 0.0 seconds
# Total time to run was 974.8 seconds

# %%
Total.tail(30)
# Out:
#       Unnamed: 0  Total_Activity      mo99     tc99m     xe133      ce143  \
# 1559    1820.000       60.629492  0.050051  0.048395  0.622988   0.000292
# 1560    1820.636     1859.060448  1.822280  0.886520  0.786192   3.140710
# 1561    1821.273     1940.724785  3.334730  2.198100  1.264150   5.482290
# 1562    1821.909     1982.404473  4.623040  3.417830  1.904100   7.181820
# 1563    1822.545     2008.770154  5.720340  4.474410  2.614440   8.415440
# 1564    1823.182     2027.679048  6.654950  5.377290  3.342010   9.310900
# 1565    1823.818     2042.420443  7.451020  6.146940  4.056570   9.960900
# 1566    1824.455     2054.543419  8.129080  6.802440  4.741970  10.432500
# 1567    1825.091     2064.880171  8.706700  7.360890  5.389630  10.774900
# 1568    1825.727     2073.897924  9.198600  7.836580  5.996350  11.023500
# 1569    1826.364     2081.889601  9.617600  8.241650  6.561150  11.203900
# 1570    1827.000     2089.063005  9.974500  8.586700  7.085120  11.334700
# 1571    1827.038       78.549956  1.165200  1.014200  0.838770   1.314300
# 1572    1827.077      562.686146  9.786400  8.605000  7.142360  10.986100
# 1573    1827.115       59.974840  1.142900  1.014100  0.845150   1.265000
# 1574    1827.154      472.149053  9.598400  8.587700  7.192820  10.569100
# 1575    1827.192       52.377467  1.120900  1.010300  0.850680   1.217000
# 1576    1827.231      421.704373  9.414000  8.542400  7.236120  10.167500
# 1577    1827.269       47.484438  1.099400  1.003600  0.855350   1.170700
# 1578    1827.308      386.241069  9.233200  8.474960  7.272280   9.781300
# 1579    1827.346       43.835478  1.078300  0.994590  0.859210   1.126300
# 1580    1827.385      358.699460  9.055900  8.390280  7.301750   9.409600
# 1581    1827.423       40.917642  1.057500  0.983770  0.862310   1.083500
# 1582    1827.462      336.214203  8.881800  8.292320  7.324990   9.052100
# 1583    1827.538      279.895436  7.684000  7.219000  6.476700   7.685900
# 1584    1827.615      265.634159  7.536400  7.116700  6.487200   7.393900
# 1585    1827.692      253.253773  7.391700  7.009400  6.493200   7.113000
# 1586    1827.769      242.384311  7.249700  6.898500  6.495000   6.842800
# 1587    1827.846      232.750091  7.110400  6.785100  6.492900   6.582800
# 1588    1827.923      224.140516  6.973800  6.670300  6.487100   6.332700
#
#               i133      i132     te132         xe135  ...     kr100  kr78  \
# 1559  6.807450e-07  0.072801  0.070627  1.123060e-15  ...  0.000000     0
# 1560  4.944160e+00  0.958220  1.149330  5.166000e+00  ...  0.000002     0
# 1561  8.169390e+00  1.928700  2.092830  9.702000e+00  ...  0.000002     0
# 1562  1.010810e+01  2.776130  2.914980  1.170640e+01  ...  0.000002     0
# 1563  1.127350e+01  3.514580  3.631410  1.245130e+01  ...  0.000002     0
# 1564  1.197370e+01  4.158090  4.255750  1.270860e+01  ...  0.000002     0
# 1565  1.239540e+01  4.718810  4.799700  1.279370e+01  ...  0.000002     0
# 1566  1.264820e+01  5.207500  5.273760  1.282100e+01  ...  0.000002     0
# 1567  1.280020e+01  5.633260  5.686820  1.283000e+01  ...  0.000002     0
# 1568  1.289200e+01  6.004240  6.046790  1.283330e+01  ...  0.000002     0
# 1569  1.294740e+01  6.327580  6.360390  1.283350e+01  ...  0.000002     0
# 1570  1.298030e+01  6.609200  6.633710  1.283450e+01  ...  0.000002     0
# 1571  1.510400e+00  0.782130  0.778600  1.507700e+00  ...  0.000000     0
# 1572  1.251090e+01  6.599880  6.528250  1.264190e+01  ...  0.000000     0
# 1573  1.435300e+00  0.777930  0.765750  1.469200e+00  ...  0.000000     0
# 1574  1.182730e+01  6.545750  6.420500  1.220780e+01  ...  0.000000     0
# 1575  1.353300e+00  0.769890  0.753110  1.407700e+00  ...  0.000000     0
# 1576  1.113700e+01  6.468050  6.314570  1.161490e+01  ...  0.000000     0
# 1577  1.273500e+00  0.759860  0.740680  1.331100e+00  ...  0.000000     0
# 1578  1.047630e+01  6.378330  6.210350  1.092260e+01  ...  0.000000     0
# 1579  1.197700e+00  0.748820  0.728460  1.245600e+00  ...  0.000000     0
# 1580  9.852200e+00  6.282700  6.107820  1.017430e+01  ...  0.000000     0
# 1581  1.126300e+00  0.737310  0.716440  1.155600e+00  ...  0.000000     0
# 1582  9.264600e+00  6.184380  6.007100  9.403800e+00  ...  0.000000     0
# 1583  7.684800e+00  5.365600  5.209200  7.615700e+00  ...  0.000000     0
# 1584  7.226300e+00  5.278600  5.123200  6.954500e+00  ...  0.000000     0
# 1585  6.795100e+00  5.192400  5.038600  6.320600e+00  ...  0.000000     0
# 1586  6.389700e+00  5.107200  4.955500  5.720900e+00  ...  0.000000     0
# 1587  6.008400e+00  5.023200  4.873700  5.159500e+00  ...  0.000000     0
# 1588  5.649900e+00  4.940500  4.793300  4.638600e+00  ...  0.000000     0
#
#               kr79m  kr80  kr82  kr83  kr84  kr86     zr99  Time (days)
# 1559   0.000000e+00     0     0     0     0     0   0.0000     1820.000
# 1560   4.767500e-15     0     0     0     0     0  11.1624     1820.636
# 1561   4.768000e-15     0     0     0     0     0  11.1624     1821.273
# 1562   4.768900e-15     0     0     0     0     0  11.1624     1821.909
# 1563   4.770000e-15     0     0     0     0     0  11.1624     1822.545
# 1564   4.771300e-15     0     0     0     0     0  11.1624     1823.182
# 1565   4.772700e-15     0     0     0     0     0  11.1624     1823.818
# 1566   4.774300e-15     0     0     0     0     0  11.1624     1824.455
# 1567   4.776000e-15     0     0     0     0     0  11.1624     1825.091
# 1568   4.777900e-15     0     0     0     0     0  11.1624     1825.727
# 1569   4.779700e-15     0     0     0     0     0  11.1624     1826.364
# 1570   4.781600e-15     0     0     0     0     0  11.1624     1827.000
# 1571   1.557500e-35     0     0     0     0     0   0.0000     1827.038
# 1572   1.532600e-55     0     0     0     0     0   0.0000     1827.077
# 1573   1.508100e-75     0     0     0     0     0   0.0000     1827.115
# 1574   1.484000e-95     0     0     0     0     0   0.0000     1827.154
# 1575  1.460300e-115     0     0     0     0     0   0.0000     1827.192
# 1576  1.436900e-135     0     0     0     0     0   0.0000     1827.231
# 1577  1.413900e-155     0     0     0     0     0   0.0000     1827.269
# 1578  1.391300e-175     0     0     0     0     0   0.0000     1827.308
# 1579  1.369100e-195     0     0     0     0     0   0.0000     1827.346
# 1580  1.347200e-215     0     0     0     0     0   0.0000     1827.385
# 1581  1.325700e-235     0     0     0     0     0   0.0000     1827.423
# 1582  1.304500e-255     0     0     0     0     0   0.0000     1827.462
# 1583   0.000000e+00     0     0     0     0     0   0.0000          NaN
# 1584   0.000000e+00     0     0     0     0     0   0.0000          NaN
# 1585   0.000000e+00     0     0     0     0     0   0.0000          NaN
# 1586   0.000000e+00     0     0     0     0     0   0.0000          NaN
# 1587   0.000000e+00     0     0     0     0     0   0.0000          NaN
# 1588   0.000000e+00     0     0     0     0     0   0.0000          NaN
#
# [30 rows x 1153 columns]
